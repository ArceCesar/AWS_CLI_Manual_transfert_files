# %% [markdown]
# # Script to transfer manually using AWS CLI (Prompt)

# %% [markdown]
# ## **Table of Contents :<a name="return"></a>**
# 1. [Move All Files Inbound to Archive - Dev using AWS CLI](#move_files_dev)
# 1. [Move All Files Inbound to Archive - QA using AWS CLI](#move_files_qa)
# 1. [Copy Files QA to Dev using AWS CLI (Inbound - CDS)](#move_files_CDS_qa_dev)
# 1. [Copy Files QA to Dev using AWS CLI (Inbound - MDM)](#move_files_MDM_qa_dev)
# 1. [Remove Buckets using AWS CLI](#remove_buckets)
# 1. [Create Treeview mapping Dev using AWS CLI (Archive)](#create_treeview_files_dev_archive)
# 1. [Create Treeview mapping Dev using AWS CLI (Inbound)](#create_treeview_files_dev_inbound)
# 1. [Create Treeview mapping Staging using AWS CLI (Archive)](#create_treeview_files_staging_archive)
# 1. [Create Treeview mapping Staging using AWS CLI (Inbound)](#create_treeview_files_staging_inbound)

# %% [markdown]
# #### --> Target: Create a TEXT File to move from Source to Target using AWS CLI <br>
# aws s3 mv  s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/Financials/Costing/
#    s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/Financials/Costing/ --recursive

# %% [markdown]
# ## Move All Files from Inbound to Archive (Dev) <a name="move_files_dev"></a>

# %% [markdown]
# Target : "s3://agropur-global-nonprod-account-dev-sapco"

# %%
# Import Libraries
import sys
import pandas as pd
import boto3
import os

bucketname = "s3://agropur-global-nonprod-account-dev-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
dev_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23')
new_dev_source= dev_source[['source','target']]

with open('Move_Files_Dev_Inbound_to_Archive.txt', 'w') as f:
    for i in range(len(new_dev_source)):
        line = "aws s3 mv"+ " "+ bucketname + new_dev_source.loc[i, "source"] + " " + bucketname \
        + new_dev_source.loc[i, "target"] + " --recursive"
        f.write(line + "\n")
        
with open('Move_Files_Dev_Inbound_to_Archive.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')
        
for i in range(len(new_dev_source)):
    print('aws s3 mv ', bucketname, new_dev_source.loc[i, "source"], ' ', bucketname, new_dev_source.loc[i, "target"], ' --recursive', sep='')
# Out:
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/CEPC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/CEPC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/CEPCT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/CEPCT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/DRY_COMPTYPE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/DRY_COMPTYPE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/MCH1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/MCH1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/SCWM_TPMTYP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/SCWM_TPMTYP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/SWOR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/SWOR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T003/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T003/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T003O/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T003O/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T005/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T005/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T005S/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T005S/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T023/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T023/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T023T/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T023T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T024/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T024/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T024D/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T024D/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T025/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T025/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T025T/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T025T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T042Z/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T042Z/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T077K/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T077K/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T077Y/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T077Y/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T134/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T134/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T134T/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T134T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T141/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T141/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T151/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T151/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T156T/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T156T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T157D/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T157D/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T171/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T171/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T179/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T179/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T179T/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T179T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T438A/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T438A/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T438T/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T438T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T439A/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T439A/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T460A/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T460A/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T461P/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T461P/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T681A s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T681A --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T685T/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T685T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TB001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TB001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TB003/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TB003/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TCO43/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TCO43/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TCURC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TCURC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/THIT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/THIT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TKUKL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TKUKL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TPAR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TPAR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TPTM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TPTM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TSPA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TSPA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TSPAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TSPAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVAK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVAK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVAKT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVAKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVAU/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVAU/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVBUR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVBUR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVK0/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVK0/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVK9/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVK9/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVKBT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVKBT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVKOT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVKOT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVKWZ/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVKWZ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVRO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVRO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVROT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVROT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVSB/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVSB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVSBT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVSBT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVSTT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVSTT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVTW/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVTW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVTWT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVTWT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVV1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVV1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVV2/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVV2/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/COSTING/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/FINANCIAL/COSTING/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/PRICING/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/PRICING/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/ANALYSIS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/ANALYSIS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/INVENTORY/BALANCE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/INVENTORY/BALANCE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/INVENTORY/TRANSACTION/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/INVENTORY/TRANSACTION/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/OVERVIEW/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/OVERVIEW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/MATERIALLIST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/MATERIALLIST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/QUALITYMANAGEMENT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/QUALITYMANAGEMENT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/OPERATIONSLIST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/OPERATIONSLIST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/INVOICELINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/INVOICELINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASEORDER/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASEORDER/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASERECEIPT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASERECEIPT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/INVOICELINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/SALE/INVOICELINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/ORDERLINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/SALE/ORDERLINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/SHIPLINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/SALE/SHIPLINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/FIN_T001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/FIN_T001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009B/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009B/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009C/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009C/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A526/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A526/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A528/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A528/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A531/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A531/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A532/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A532/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A533/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A533/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A534/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A534/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A537/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A537/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A541/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A541/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A542/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A542/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A701/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A701/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A702/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A702/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A703/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A703/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR2/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR2/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR6/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR6/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADRC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADRC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/AUSP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/AUSP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B501/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B501/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B503/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B503/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B504/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B504/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B511/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B511/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B512/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B512/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT000/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT000/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT020/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT020/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT100/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT100/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDIPHONE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDIPHONE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP12/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP12/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP13/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP13/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP21/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP21/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPAR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPAR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPP1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPP1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDSDC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDSDC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNA1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNA1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB5/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB5/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMTA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMTA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVI/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVI/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVV/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVV/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONDH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONDH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH900/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH900/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH903/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH903/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/NACH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/NACH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T682I/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T682I/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T685/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T685/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/TVKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/TVKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UKMBPCMS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UKMBPCMS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AFPO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AFPO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUFK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUFK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUSP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUSP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CABN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CABN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CAUFV/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CAUFV/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRHD/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRHD/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRTX/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRTX/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KLAH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KLAH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAKT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAPL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAPL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARD/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARD/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MCH1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MCH1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MBEW/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MBEW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MKAL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MKAL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MLAN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MLAN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MVKE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MVKE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLMK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLMK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLPO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLPO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVMT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVMT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVV/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVV/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTB/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMZ/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMZ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/RESB/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/RESB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SPRAS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SPRAS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STPO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STPO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/TCRCOT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/TCRCOT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A017/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A017/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A018/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A018/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR2/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR2/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR6/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR6/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADRC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADRC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT000/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT000/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT100/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT100/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EORD/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EORD/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KNBK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KNBK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFA1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFA1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFB1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFB1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBW/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFM1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFM1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T001W/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T001W/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T024E/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T024E/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/WYT3/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/WYT3/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANEP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANEP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLB/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLZ/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLZ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BKPF/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BKPF/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BNKA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BNKA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSEG/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSEG/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSET/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSET/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRHI/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRHI/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PROJ/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PROJ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRPS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRPS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKA1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKA1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKB1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKB1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSEG/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSEG/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSIK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSIK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/AUSP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/AUSP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/CABN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/CABN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/KLAH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/KLAH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MCHA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MCHA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MKPF/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MKPF/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MSEG/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MSEG/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONED/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONED/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONER/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONER/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/AQUA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/AQUA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/LAGP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/LAGP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/QUAN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/QUAN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/T001L/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/T001L/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/TVST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/TVST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/TEST/T001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/TEST/T001/ --recursive

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ## To Move All Files from Inbound to Archive (QA) <a name="move_files_qa"></a>

# %% [markdown]
# Target : "s3://agropur-global-nonprod-account-staging-sapco"

# %%
# Import Libraries
import sys
import pandas as pd
import boto3
import os

bucketname = "s3://agropur-global-nonprod-account-staging-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
staging_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23')
new_staging_source= staging_source[['source','target']]

with open('Move_Files_QA_Inbound_to_Archive.txt', 'w') as f:
    for i in range(len(new_staging_source)):
        line = "aws s3 mv"+ " "+ bucketname + new_staging_source.loc[i, "source"] + " " + bucketname \
        + new_dev_source.loc[i, "target"] + " --recursive"
        f.write(line + "\n")

with open('Move_Files_QA_Inbound_to_Archive.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')
    
for i in range(len(new_staging_source)):
    print('aws s3 mv ', bucketname, new_staging_source.loc[i, "source"], ' ', bucketname, new_dev_source.loc[i, "target"], ' --recursive', sep='')
# Out:
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/CEPC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/CEPC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/CEPCT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/CEPCT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/DRY_COMPTYPE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/DRY_COMPTYPE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/MCH1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/MCH1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/SCWM_TPMTYP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/SCWM_TPMTYP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/SWOR/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/SWOR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T003/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T003/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T003O/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T003O/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T005/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T005/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T005S/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T005S/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T023/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T023/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T023T/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T023T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T024/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T024/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T024D/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T024D/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T025/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T025/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T025T/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T025T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T042Z/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T042Z/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T077K/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T077K/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T077Y/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T077Y/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T134/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T134/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T134T/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T134T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T141/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T141/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T151/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T151/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T156T/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T156T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T157D/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T157D/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T171/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T171/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T179/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T179/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T179T/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T179T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T438A/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T438A/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T438T/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T438T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T439A/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T439A/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T460A/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T460A/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T461P/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T461P/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T681A s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T681A --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T685T/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T685T/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TB001/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TB001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TB003/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TB003/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TCO43/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TCO43/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TCURC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TCURC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/THIT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/THIT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TKUKL/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TKUKL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TPAR/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TPAR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TPTM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TPTM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TSPA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TSPA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TSPAT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TSPAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVAK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVAK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVAKT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVAKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVAU/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVAU/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVBUR/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVBUR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVK0/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVK0/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVK9/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVK9/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVKBT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVKBT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVKOT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVKOT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVKWZ/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVKWZ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVRO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVRO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVROT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVROT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVSB/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVSB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVSBT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVSBT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVSTT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVSTT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVTW/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVTW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVTWT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVTWT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVV1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVV1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVV2/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVV2/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/COSTING/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/FINANCIAL/COSTING/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/PRICING/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/PRICING/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/ANALYSIS/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/ANALYSIS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/INVENTORY/BALANCE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/INVENTORY/BALANCE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/INVENTORY/TRANSACTION/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/INVENTORY/TRANSACTION/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/OVERVIEW/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/OVERVIEW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/MATERIALLIST/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/MATERIALLIST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/QUALITYMANAGEMENT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/QUALITYMANAGEMENT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/OPERATIONSLIST/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/OPERATIONSLIST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/INVOICELINE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/INVOICELINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASEORDER/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASEORDER/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASERECEIPT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASERECEIPT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/INVOICELINE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/SALE/INVOICELINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/ORDERLINE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/SALE/ORDERLINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/SHIPLINE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/SALE/SHIPLINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/FIN_T001/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/FIN_T001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T001/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009B/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009B/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009C/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009C/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A526/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A526/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A528/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A528/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A531/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A531/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A532/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A532/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A533/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A533/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A534/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A534/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A537/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A537/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A541/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A541/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A542/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A542/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A701/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A701/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A702/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A702/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A703/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A703/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR2/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR2/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR6/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR6/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADRC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADRC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/AUSP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/AUSP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B501/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B501/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B503/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B503/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B504/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B504/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B511/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B511/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B512/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B512/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT000/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT000/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT020/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT020/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT100/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT100/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDIPHONE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDIPHONE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP12/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP12/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP13/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP13/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP21/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP21/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPAR/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPAR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPP1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPP1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDSDC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDSDC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNA1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNA1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB5/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB5/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMTA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMTA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVI/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVI/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVV/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVV/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONDH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONDH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH001/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH001/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH900/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH900/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH903/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH903/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/NACH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/NACH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXL/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T682I/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T682I/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T685/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T685/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/TVKO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/TVKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UKMBPCMS/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UKMBPCMS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AFPO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AFPO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUFK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUFK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUSP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUSP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CABN/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CABN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CAUFV/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CAUFV/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRHD/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRHD/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRTX/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRTX/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KLAH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KLAH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAKT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAPL/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAPL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARD/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARD/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAST/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MCH1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MCH1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MBEW/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MBEW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MKAL/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MKAL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MLAN/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MLAN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MVKE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MVKE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLKO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLMK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLMK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLPO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLPO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVMT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVMT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVV/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVV/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMAT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTB/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMZ/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMZ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/RESB/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/RESB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SPRAS/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SPRAS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STKO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STKO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STPO/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STPO/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXL/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/TCRCOT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/TCRCOT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A017/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A017/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A018/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A018/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR2/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR2/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR6/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR6/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADRC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADRC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT000/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT000/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT100/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT100/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EORD/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EORD/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KNBK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KNBK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFA1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFA1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFB1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFB1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBW/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBW/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFM1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFM1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T001W/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T001W/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T024E/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T024E/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/WYT3/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/WYT3/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANEP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANEP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLB/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLB/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLZ/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLZ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BKPF/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BKPF/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BNKA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BNKA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSEG/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSEG/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSET/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSET/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIS/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKS/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRHI/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRHI/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PROJ/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PROJ/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRPS/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRPS/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKA1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKA1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKAT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKB1/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKB1/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSEG/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSEG/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSIK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSIK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/AUSP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/AUSP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/CABN/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/CABN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/KLAH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/KLAH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MCHA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MCHA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MKPF/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MKPF/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MSEG/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MSEG/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TR/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONED/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONED/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONER/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONER/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONE/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONE/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/AQUA/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/AQUA/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/LAGP/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/LAGP/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/QUAN/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/QUAN/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/T001L/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/T001L/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/TVST/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/TVST/ --recursive
# aws s3 mv s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/TEST/T001/ s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/TEST/T001/ --recursive

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ## Copy All Files CDS from Staging QA to Staging Dev <a name="move_files_CDS_qa_dev"></a>

# %%
# Import Libraries
import sys
import pandas as pd
import boto3
import os

bucketname = "s3://agropur-global-nonprod-account-dev-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
staging_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23_CDS')
new_staging_source= staging_source[['source_staging_path','source_dev_path']]

with open('Copy_CDS_Files_Inbound_QA_to_Dev.txt', 'w') as f:
    for i in range(len(new_staging_source)):
        line = "aws s3 cp"+ " "+ new_staging_source.loc[i, "source_staging_path"] + " " + new_staging_source.loc[i, "source_dev_path"] + " --recursive"
        f.write(line + "\n")

with open('Copy_CDS_Files_Inbound_QA_to_Dev.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')
    
for i in range(len(new_staging_source)):
    print('aws s3 cp ', new_staging_source.loc[i, "source_staging_path"], ' ', new_staging_source.loc[i, "source_dev_path"], ' --recursive', sep='')
# Out:
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/COSTING/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/COSTING/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/PRICING/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/PRICING/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/ANALYSIS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/ANALYSIS/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/INVENTORY/BALANCE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/INVENTORY/BALANCE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/INVENTORY/TRANSACTION/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/INVENTORY/TRANSACTION/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/OVERVIEW/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/OVERVIEW/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/MATERIALLIST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/MATERIALLIST/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/QUALITYMANAGEMENT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/QUALITYMANAGEMENT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/OPERATIONSLIST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/OPERATIONSLIST/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/INVOICELINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/INVOICELINE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASEORDER/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASEORDER/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASERECEIPT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASERECEIPT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/INVOICELINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/INVOICELINE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/ORDERLINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/ORDERLINE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/SHIPLINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/SHIPLINE/ --recursive

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ## Copy All Files MDM from Staging QA to Staging Dev <a name="move_files_MDM_qa_dev"></a>

# %%
# Import Libraries
import sys
import pandas as pd
import boto3
import os

bucketname = "s3://agropur-global-nonprod-account-dev-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
staging_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23_MDM')
new_staging_source= staging_source[['source_staging_path','source_dev_path']]

with open('Copy_MDM_Files_Inbound_QA_to_Dev.txt', 'w') as f:
    for i in range(len(new_staging_source)):
        line = "aws s3 cp"+ " "+ new_staging_source.loc[i, "source_staging_path"] + " " + new_staging_source.loc[i, "source_dev_path"] + " --recursive"
        f.write(line + "\n")

with open('Copy_MDM_Files_Inbound_QA_to_Dev.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')
    
for i in range(len(new_staging_source)):
    print('aws s3 cp ', new_staging_source.loc[i, "source_staging_path"], ' ', new_staging_source.loc[i, "source_dev_path"], ' --recursive', sep='')
# Out:
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/FIN_T001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/FIN_T001/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T001/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009B/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009B/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009C/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009C/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A526/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A526/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A528/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A528/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A531/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A531/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A532/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A532/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A533/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A533/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A534/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A534/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A537/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A537/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A541/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A541/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A542/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A542/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A701/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A701/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A702/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A702/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A703/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A703/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR2/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR2/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR6/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR6/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADRC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADRC/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/AUSP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/AUSP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B501/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B501/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B503/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B503/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B504/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B504/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B511/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B511/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B512/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B512/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT000/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT000/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT020/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT020/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT100/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT100/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDIPHONE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDIPHONE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP12/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP12/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP13/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP13/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP21/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP21/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPAR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPAR/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPP1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPP1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDSDC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDSDC/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNA1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNA1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB5/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB5/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMTA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMTA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVI/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVI/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVV/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVV/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONDH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONDH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONM/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH001/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH900/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH900/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH903/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH903/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/NACH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/NACH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXL/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T682I/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T682I/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T685/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T685/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/TVKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/TVKO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UKMBPCMS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UKMBPCMS/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AFPO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AFPO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUFK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUFK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUSP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUSP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CABN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CABN/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CAUFV/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CAUFV/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRHD/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRHD/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRTX/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRTX/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KLAH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KLAH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAKT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAKT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAPL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAPL/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARC/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARD/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARD/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARM/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAST/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MCH1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MCH1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MBEW/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MBEW/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MKAL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MKAL/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MLAN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MLAN/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MVKE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MVKE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLKO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLMK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLMK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLPO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLPO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVM/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVMT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVMT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVV/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVV/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMAT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTB/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTB/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMZ/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMZ/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/RESB/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/RESB/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SPRAS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SPRAS/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STKO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STKO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STPO/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STPO/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXL/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/TCRCOT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/TCRCOT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A017/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A017/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A018/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A018/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR2/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR2/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR6/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR6/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADRC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADRC/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT000/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT000/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT100/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT100/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EORD/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EORD/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KNBK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KNBK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONM/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFA1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFA1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFB1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFB1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBW/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBW/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFM1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFM1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T001W/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T001W/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T024E/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T024E/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/WYT3/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/WYT3/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANEP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANEP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLB/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLB/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLC/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLZ/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLZ/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BKPF/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BKPF/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BNKA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BNKA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSEG/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSEG/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSET/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSET/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIS/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKS/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRHI/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRHI/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PROJ/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PROJ/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRPS/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRPS/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKA1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKA1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKAT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKB1/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKB1/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSEG/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSEG/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSIK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSIK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/AUSP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/AUSP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/CABN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/CABN/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/KLAH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/KLAH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MCHA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MCHA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MKPF/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MKPF/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MSEG/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MSEG/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TR/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONED/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONED/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONER/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONER/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONE/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONE/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/AQUA/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/AQUA/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/LAGP/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/LAGP/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/QUAN/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/QUAN/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/T001L/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/T001L/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/TVST/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/TVST/ --recursive
# aws s3 cp s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/TEST/T001/ s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/TEST/T001/ --recursive

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# # Remove Bucket using CLI <a name="remove_buckets"></a>

# %% [markdown]
# aws s3 rb s3://mybucket

# %% [markdown]
# Erase a Folder in a bucket: (WARNING)

# %% [markdown]
# ### Remove Bucket Dev

# %%
# aws s3 rm s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/ --recursive
# aws s3 rm s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/ --recursive

# %% [markdown]
# ### Remove Bucket Staging

# %%
# aws s3 rm s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/ --recursive
# aws s3 rm s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/ --recursive

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ## Create Treeview files - dev / Archive <a name="create_treeview_files_dev_archive"></a>

# %%
# Import Libraries
import sys
import pandas as pd
import boto3

bucketname = "s3://agropur-global-nonprod-account-dev-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
dev_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23')
dev_archive_source= dev_source[['target']]

with open('Create_mapping_Dev_Archive.txt', 'w') as f:
    for i in range(len(dev_archive_source)):
        line = "aws s3 cp ." + " " + bucketname + dev_archive_source.loc[i, "target"] + " " + '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*"--include ".bash_history"' 
        f.write(line + "\n")

with open('Create_mapping_Dev_Archive.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')

for i in range(len(dev_archive_source)):
    print('aws s3 cp . ', bucketname, dev_archive_source.loc[i, "target"], ' ', '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"', sep='')
# Out:
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/CEPC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/CEPCT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/DRY_COMPTYPE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/SCWM_TPMTYP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/SWOR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T003O/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T005/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T005S/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T023/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T023T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T024/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T024D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T025/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T025T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T042Z/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T077K/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T077Y/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T134/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T134T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T141/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T151/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T156T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T157D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T171/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T179/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T179T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T438A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T438T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T439A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T460A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T461P/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T681A --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/T685T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TB001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TB003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TCO43/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TCURC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/THIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TKUKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TPTM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TSPA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TSPAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVAU/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVBUR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVK0/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVK9/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVKBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVKOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVKWZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVRO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVROT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVSB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVSBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVSTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVTW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVTWT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVV1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/CONFIGFILES/TVV2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/FINANCIAL/COSTING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/PRICING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/ANALYSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/INVENTORY/BALANCE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/INVENTORY/TRANSACTION/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/OVERVIEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/MATERIALLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/QUALITYMANAGEMENT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MANUFACTURING/OPERATIONSLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASEORDER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASERECEIPT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/SALE/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/SALE/ORDERLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/SALE/SHIPLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/FIN_T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009B/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009C/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A526/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A528/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A531/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A532/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A533/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A534/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A537/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A541/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A542/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A701/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A702/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A703/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B501/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B503/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B504/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B511/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B512/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT020/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDIPHONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP12/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP13/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP21/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPP1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDSDC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB5/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMTA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONDH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH900/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH903/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/NACH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T682I/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T685/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/TVKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UKMBPCMS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AFPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUFK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CAUFV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRHD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRTX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAPL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MBEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MKAL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MLAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MVKE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/RESB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SPRAS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/TCRCOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A017/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A018/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EORD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KNBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFM1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T001W/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T024E/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/WYT3/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BNKA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSET/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRHI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PROJ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRPS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MCHA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONED/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/AQUA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/LAGP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/QUAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/T001L/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/TVST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/MASTER_DATA_TABLES/TEST/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ## Create Treeview files - dev / Inbound <a name="create_treeview_files_dev_inbound"></a>

# %%
# Import Libraries
import sys
import pandas as pd
import boto3

bucketname = "s3://agropur-global-nonprod-account-dev-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
dev_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23')
dev_inbound_source= dev_source[['source']]

with open('Create_mapping_Dev_Inbound.txt', 'w') as f:
    for i in range(len(dev_inbound_source)):
        line = "aws s3 cp ." + " " + bucketname + dev_inbound_source.loc[i, "source"] + " " + '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*"--include ".bash_history"' 
        f.write(line + "\n")

with open('Create_mapping_Dev_Inbound.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')
    
for i in range(len(dev_inbound_source)):
    print('aws s3 cp . ', bucketname, dev_inbound_source.loc[i, "source"], ' ', '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"', sep='')
# Out:
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/CEPC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/CEPCT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/DRY_COMPTYPE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/SCWM_TPMTYP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/SWOR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T003O/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T005/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T005S/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T023/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T023T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T024/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T024D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T025/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T025T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T042Z/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T077K/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T077Y/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T134/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T134T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T141/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T151/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T156T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T157D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T171/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T179/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T179T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T438A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T438T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T439A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T460A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T461P/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T681A --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/T685T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TB001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TB003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TCO43/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TCURC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/THIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TKUKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TPTM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TSPA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TSPAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVAU/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVBUR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVK0/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVK9/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVKBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVKOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVKWZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVRO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVROT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVSB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVSBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVSTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVTW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVTWT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVV1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/CONFIGFILES/TVV2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/COSTING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/PRICING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/ANALYSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/INVENTORY/BALANCE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/INVENTORY/TRANSACTION/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/OVERVIEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/MATERIALLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/QUALITYMANAGEMENT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MANUFACTURING/OPERATIONSLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASEORDER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASERECEIPT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/ORDERLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/SALE/SHIPLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/FIN_T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009B/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009C/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A526/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A528/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A531/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A532/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A533/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A534/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A537/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A541/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A542/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A701/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A702/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A703/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B501/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B503/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B504/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B511/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B512/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT020/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDIPHONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP12/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP13/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP21/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPP1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDSDC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB5/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMTA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONDH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH900/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH903/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/NACH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T682I/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T685/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/TVKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UKMBPCMS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AFPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUFK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CAUFV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRHD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRTX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAPL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MBEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MKAL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MLAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MVKE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/RESB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SPRAS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/TCRCOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A017/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A018/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EORD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KNBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFM1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T001W/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T024E/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/WYT3/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BNKA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSET/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRHI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PROJ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRPS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MCHA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONED/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/AQUA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/LAGP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/QUAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/T001L/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/TVST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/TEST/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ## Create Treeview files - staging / Inbound <a name="create_treeview_files_staging_inbound"></a>

# %%
# Import Libraries
import sys
import pandas as pd
import boto3

bucketname = "s3://agropur-global-nonprod-account-staging-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
staging_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23')
staging_inbound_source= staging_source[['source']]

with open('Create_mapping_Staging_Inbound.txt', 'w') as f:
    for i in range(len(staging_inbound_source)):
        line = "aws s3 cp ." + " " + bucketname + staging_inbound_source.loc[i, "source"] + " " + '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*"--include ".bash_history"' 
        f.write(line + "\n")

with open('Create_mapping_Staging_Inbound.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')
    
for i in range(len(staging_inbound_source)):
    print('aws s3 cp . ', bucketname, staging_inbound_source.loc[i, "source"], ' ', '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"', sep='')
# Out:
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/CEPC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/CEPCT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/DRY_COMPTYPE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/SCWM_TPMTYP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/SWOR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T003O/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T005/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T005S/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T023/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T023T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T024/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T024D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T025/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T025T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T042Z/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T077K/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T077Y/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T134/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T134T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T141/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T151/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T156T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T157D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T171/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T179/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T179T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T438A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T438T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T439A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T460A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T461P/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T681A --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/T685T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TB001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TB003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TCO43/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TCURC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/THIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TKUKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TPTM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TSPA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TSPAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVAU/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVBUR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVK0/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVK9/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVKBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVKOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVKWZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVRO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVROT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVSB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVSBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVSTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVTW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVTWT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVV1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/CONFIGFILES/TVV2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/COSTING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/PRICING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/FINANCIAL/PROFITABILITY/ANALYSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/INVENTORY/BALANCE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/INVENTORY/TRANSACTION/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/OVERVIEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/MATERIALLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/QUALITYMANAGEMENT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MANUFACTURING/OPERATIONSLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASEORDER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/PROCUREMENTANDSPEND/PURCHASERECEIPT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/ORDERLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/SALE/SHIPLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/FIN_T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009B/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/FIN/T009C/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A526/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A528/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A531/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A532/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A533/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A534/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A537/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A541/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A542/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A701/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A702/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/A703/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B501/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B503/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B504/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B511/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/B512/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT020/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDIPHONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP12/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP13/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDP21/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDPP1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/EDSDC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNB5/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNMTA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KNVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONDH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH900/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/KOTH903/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/NACH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T682I/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/T685/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/TVKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/UKMBPCMS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AFPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUFK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CAUFV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRCO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRHD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/CRTX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAPL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MARM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MAST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MBEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MKAL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MLAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/MVKE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/PLPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QCVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QMTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/QPMZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/RESB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/SPRAS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTM/TCRCOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A017/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/A018/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/EORD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KNBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFBW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/LFM1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T001W/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/T024E/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/PTP/WYT3/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ANLZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BNKA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSET/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/BSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/CSKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRHI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PROJ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/PRPS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/SKB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/RTR/ZBSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MCHA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/MSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONED/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCMB/ZONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/AQUA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/LAGP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/SCWM/QUAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/T001L/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/SC/TVST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Inbound/MASTER_DATA_TABLES/TEST/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ## Create Treeview files - staging / Archive <a name="create_treeview_files_staging_archive"></a>

# %%
# Import Libraries
import sys
import pandas as pd
import boto3

bucketname = "s3://agropur-global-nonprod-account-staging-sapco"
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucketname)
staging_source = pd.read_excel("AWS_S3_Treeview_mapping.xlsx", sheet_name='14Apr23')
staging_archive_source= staging_source[['target']]

with open('Create_mapping_Staging_Archive.txt', 'w') as f:
    for i in range(len(staging_archive_source)):
        line = "aws s3 cp ." + " " + bucketname + staging_archive_source.loc[i, "target"] + " " + '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*"--include ".bash_history"' 
        f.write(line + "\n")

with open('Create_mapping_Staging_Archive.txt', 'a') as file:
    file.write('aws s3 ls ' + bucketname + '\n')
    
for i in range(len(staging_archive_source)):
    print('aws s3 cp . ', bucketname, staging_archive_source.loc[i, "target"], ' ', '--region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"', sep='')
# Out:
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/CEPC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/CEPCT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/DRY_COMPTYPE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/SCWM_TPMTYP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/SWOR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T003O/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T005/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T005S/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T023/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T023T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T024/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T024D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T025/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T025T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T042Z/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T077K/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T077Y/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T134/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T134T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T141/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T151/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T156T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T157D/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T171/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T179/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T179T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T438A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T438T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T439A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T460A/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T461P/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T681A --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/T685T/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TB001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TB003/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TCO43/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TCURC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/THIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TKUKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TPTM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TSPA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TSPAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVAU/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVBUR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVK0/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVK9/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVKBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVKOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVKWZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVRO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVROT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVSB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVSBT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVSTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVTW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVTWT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVV1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/CONFIGFILES/TVV2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/FINANCIAL/COSTING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/PRICING/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/FINANCIAL/PROFITABILITY/ANALYSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/INVENTORY/BALANCE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/INVENTORY/TRANSACTION/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/OVERVIEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/MATERIALLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/QUALITYMANAGEMENT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MANUFACTURING/OPERATIONSLIST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASEORDER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/PROCUREMENTANDSPEND/PURCHASERECEIPT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/SALE/INVOICELINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/SALE/ORDERLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/SALE/SHIPLINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/FIN_T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009B/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/FIN/T009C/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A526/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A528/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A531/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A532/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A533/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A534/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A537/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A541/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A542/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A701/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A702/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/A703/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B501/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B503/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B504/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B511/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/B512/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT020/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDIPHONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP12/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP13/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDP21/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPAR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDPP1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/EDSDC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNB5/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNMTA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KNVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONDH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH900/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/KOTH903/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/NACH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T682I/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/T685/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/TVKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPPROFILE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UDMBPSEGMENTS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/UKMBPCMS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/OTC/ZTCOCDCPERMIT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AFPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUFK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CAUFV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRCO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRHD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/CRTX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAPL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MARM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MAST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MCH1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MBEW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MKAL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MLAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/MVKE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/PLPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVMT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QCVV/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QMTT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/QPMZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/RESB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SAPAPO/CHARMID/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/SPRAS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STKO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STPO/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/STXL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTM/TCRCOT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A017/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/A018/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR2/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADR6/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/ADRC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT000/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/BUT100/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/DFKKBPTAXNUM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EINE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/EORD/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KNBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/KONP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFBW/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/LFM1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T001W/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/T024E/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/PTP/WYT3/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLB/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ANLZ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BNKA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSET/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/BSIS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/CSKT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRHI/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PROJ/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/PRPS/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKA1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/SKB1/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/RTR/ZBSIK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/AUSP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/CABN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/KLAH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MCHA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MKPF/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/MSEG/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/MATLWHST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRM/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPAPO/TRMCARR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SAPCND/CONDINDX/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/TOENTITY/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONED/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONEP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONER/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCMB/ZONE/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/AQUA/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/BINMAT/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/HUHDR/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/LAGP/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PAPAK/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PNPAKH/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKC/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/PVPAKL/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/SCWM/QUAN/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/T001L/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/SC/TVST/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"
# aws s3 cp . s3://agropur-global-nonprod-account-staging-sapco/SAPCO/Archive/MASTER_DATA_TABLES/TEST/T001/ --region us-east-2 --recursive --exclude ".ba*" --exclude "*.*" --include ".bash_history"

# %% [markdown]
# [[Move Up]](#return)

# %% [markdown]
# ### Remove a file (Exemple)

# %% [markdown]
# aws s3 rm s3://agropur-global-nonprod-account-dev-sapco/SAPCO/Archive/TEST_MASTERDATA_FIN/.bash_history

# %% [markdown]
# [[Move Up]](#return)
